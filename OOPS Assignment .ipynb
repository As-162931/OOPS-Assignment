# %% [markdown]
# #1 OOP is a programming paradigm that organizes code into objects, which are instances of classes. It emphasizes four key principles: encapsulation, abstraction, inheritance, and polymorphism, making code modular, reusable, and maintainable.
#
# #2 A class is a blueprint for creating objects. It defines attributes (variables) and methods (functions) that describe the behavior and state of an object
#
# #3 An object is an instance of a class, with its own unique data.
#
# my_car = Car("Toyota", "Corolla")
#
# #4 Abstraction hides implementation details and only shows essential features (e.g., defining methods without implementation in abstract classes).
#
# Encapsulation restricts direct access to object data and protects it using access specifiers (public, private, protected).
#
#
# #5. Dunder (double underscore) methods are special methods with __ before and after their names, used for operator overloading and object customization.
#
# _init_ (constructor)
#
# _str_ (string representation)
#
# _call_ (callable object)
#
#
# #6. Inheritance allows a class to inherit attributes and methods from another class, promoting code reuse.
#
# class Animal:
#     def speak(self):
#         return "Animal speaks"
#
# class Dog(Animal):
#     def speak(self):
#         return "Bark"
#
# #7. Polymorphism allows methods to have different behaviors depending on the object calling them.
#
# class Cat:
#     def speak(self):
#         return "Meow"
#
# animals = [Dog(), Cat()]
# for animal in animals:
#     print(animal.speak())  # Bark, Meow
#
# #8. Encapsulation is done using access modifiers:
#
# Public (var) – accessible everywhere
#
# Protected (_var) – suggested for internal use
#
# Private (__var) – name-mangled to prevent direct access
#
#
# class Example:
#     def _init_(self):
#         self.public = "Public"
#         self._protected = "Protected"
#         self.__private = "Private"
#
# #9. A constructor (_init_) initializes an object when created.
#
# class Person:
#     def _init_(self, name):
#         self.name = name
#
# #10. Class method (@classmethod): Works on class-level data.
#
# Static method (@staticmethod): Independent of class or instance state.
#
#
# class Example:
#     class_var = "Class Variable"
#
#     @classmethod
#     def class_method(cls):
#         return cls.class_var
#
#     @staticmethod
#     def static_method():
#         return "Static Method"
#
# #11. Python does not support method overloading directly. Instead, it uses default arguments or *args.
#
# class Math:
#     def add(self, a, b, c=0):
#         return a + b + c
#
# #12. A subclass provides a specific implementation of a method inherited from a parent class.
#
# class Parent:
#     def show(self):
#         return "Parent"
#
# class Child(Parent):
#     def show(self):
#         return "Child"
#
# #13. @property makes a method act like an attribute.
#
# class Person:
#     def _init_(self, name):
#         self._name = name
#
#     @property
#     def name(self):
#         return self._name
#
# #14. It allows code flexibility, reusability, and scalability by enabling a single interface to handle multiple data types.
#
# #15. An abstract class (via ABC) cannot be instantiated and requires subclasses to implement certain methods.
#
# from abc import ABC, abstractmethod
#
# class Animal(ABC):
#     @abstractmethod
#     def sound(self):
#         pass
#
# #16. Code reuse (inheritance)
#
# Better modularity (encapsulation)
#
# Scalability
#
# Easier maintenance
#
#
# #17. Class variable: Shared among all instances (class_var).
#
# Instance variable: Unique to each instance (self.var).
#
#
# class Example:
#     class_var = "Shared"
#
#     def _init_(self, value):
#         self.instance_var = value
#
# #18. A class inherits from multiple parent classes.
#
# class A:
#     pass
#
# class B:
#     pass
#
# class C(A, B):
#     pass
#
# #19. _str_: Readable string representation (str(obj)).
#
# _repr_: Unambiguous representation for debugging (repr(obj)).
#
#
# class Example:
#     def _str_(self):
#         return "Readable"
#
#     def _repr_(self):
#         return "Debug"
#
# #20. It calls the parent class’s method, useful in inheritance.
#
# class Parent:
#     def show(self):
#         return "Parent"
#
# class Child(Parent):
#     def show(self):
#         return super().show() + " -> Child"
#
# #21. It acts as a destructor, called when an object is deleted.
#
# class Example:
#     def _del_(self):
#         print("Object deleted")
#
# #22. @staticmethod: No access to class or instance.
#
# @classmethod: Works with the class itself (cls).
#
#
# #23. Polymorphism allows different classes to share the same method name but provide different implementations.
#
# class Bird:
#     def speak(self):
#         return "Chirp"
#
# class Dog:
#     def speak(self):
#         return "Bark"
#
# animals = [Bird(), Dog()]
# for a in animals:
#     print(a.speak())
#
# #24. Method chaining allows calling multiple methods on the same object in one statement.
#
# class Example:
#     def method1(self):
#         print("Method1")
#         return self
#
#     def method2(self):
#         print("Method2")
#         return self
#
# obj = Example()
# obj.method1().method2()
#
# #25. It makes an instance behave like a function.
#
# class Example:
#     def _call_(self):
#         return "Called"
#
# obj = Example()
# print(obj())  # Output: "Called"

# %%
#Precticle question
#1
class Animal:
    def speak(self):
        print("The animal makes a sound.")

class Dog(Animal):
    def speak(self):
        print("Bark!")

dog = Dog()
dog.speak()
# Out:
# Bark!

# %%
#2
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius
    
    def area(self):
        return 3.14 * self.radius * self.radius

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width
    
    def area(self):
        return self.length * self.widt

# %%
#3
class Vehicle:
    def __init__(self, type):
        self.type = type

class Car(Vehicle):
    def __init__(self, type, brand):
        super().__init__(type)
        self.brand = brand

class ElectricCar(Car):
    def __init__(self, type, brand, battery):
        super().__init__(type, brand)
        self.battery = battery

# %%
#4
class BankAccount:
    def __init__(self, balance=0):
        self.__balance = balance
    
    def deposit(self, amount):
        self.__balance += amount
    
    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
        else:
            print("Insufficient funds")
    
    def check_balance(self):
        return self.__balance

# %%
#5
class BankAccount:
    def __init__(self, balance=0):
        self.__balance = balance
    
    def deposit(self, amount):
        self.__balance += amount
    
    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
        else:
            print("Insufficient funds")
    
    def check_balance(self):
        return self.__balance

# %%
#6
class Instrument:
    def play(self):
        print("Playing an instrument.")

class Guitar(Instrument):
    def play(self):
        print("Strumming the guitar.")

class Piano(Instrument):
    def play(self):
        print("Playing the piano.")

# %%
#7
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b
    
    @staticmethod
    def subtract_numbers(a, b):
        return a - b

# %%
#8
class Person:
    count = 0
    
    def __init__(self, name, age):
        self.name = name
        self.age = age
        Person.count += 1
    
    @classmethod
    def total_persons(cls):
        return cls.count

# %%
#9
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator
    
    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# %%
#10
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    
    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)
    
    def __str__(self):
        return f"Vector({self.x}, {self.y})"

# %%
#11
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    
    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# %%
#12
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades
    
    def average_grade(self):
        return sum(self.grades) / len(self.grades)

# %%
#13
class Rectangle:
    def set_dimensions(self, length, width):
        self.length = length
        self.width = width
    
    def area(self):
        return self.length * self.width

# %%
#14
class Employee:
    def __init__(self, hours_worked, hourly_rate):
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate
    
    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate

class Manager(Employee):
    def __init__(self, hours_worked, hourly_rate, bonus):
        super().__init__(hours_worked, hourly_rate)
        self.bonus = bonus
    
    def calculate_salary(self):
        return super().calculate_salary() + self.bonus

# %%
#15
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity
    
    def total_price(self):
        return self.price * self.quantity

# %%
#16
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        return "Moo"

class Sheep(Animal):
    def sound(self):
        return "Baa"

# %%
#17
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published
    
    def get_book_info(self):
        return f"{self.title} by {self.author}, published in {self.year_published}"

# %%
#18
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms
